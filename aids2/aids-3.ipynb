# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("Current_Pub_Meta.csv")
herald_winrate = df[:20]
print(herald_winrate)
# Out:
#     Unnamed: 0                Name Primary Attribute  \
# 0            0             Abaddon               all
# 1            1           Alchemist               str
# 2            2  Ancient Apparition               int
# 3            3           Anti-Mage               agi
# 4            4          Arc Warden               agi
# 5            5                 Axe               str
# 6            6                Bane               all
# 7            7            Batrider               all
# 8            8         Beastmaster               all
# 9            9         Bloodseeker               agi
# 10          10       Bounty Hunter               agi
# 11          11          Brewmaster               all
# 12          12         Bristleback               str
# 13          13         Broodmother               all
# 14          14   Centaur Warrunner               str
# 15          15        Chaos Knight               str
# 16          16                Chen               all
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
plt.bar(herald_winrate['Name'], herald_winrate['Herald Win Rate'])
plt.xticks(rotation=45, ha='right')
plt.xlabel('Name of the Hero')
plt.ylabel('Herald Win Rate')
plt.title('Summary of Hero with Herald Win Rate')
plt.tight_layout()
print(name_with_winrate)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.scatter(herald_winrate['Herald Picks'], herald_winrate['Herald Win Rate'])
plt.xlabel('Number of Herald Picks')
plt.ylabel('Win Rate in Herald')
plt.title('Scatter of Herald Picks vs Herald Win Rate')
# Out:
# Text(0.5, 1.0, 'Scatter of Herald Picks vs Herald Win Rate')
